# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv('data/movie.csv')
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
index = movie.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
columns = movie.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
values = movie.values
values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
print(type(index))
print(type(columns))
print(type(values))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'pandas.core.indexes.base.Index'>
# <class 'numpy.ndarray'>

# %%
print(type(index.values))
print(type(columns.values))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
index.values.shape
# Out:
# (4916,)

# %%
index.columns.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-387a8e9a8263> in <module>
# ----> 1 index.columns.shape
#
# AttributeError: 'RangeIndex' object has no attribute 'columns'

# %%
index.columns[0].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-08c00771b18d> in <module>
# ----> 1 index.columns[0].shape
#
# AttributeError: 'RangeIndex' object has no attribute 'columns'

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movie.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
movie.head() # default value is n=5
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
director = movie.director_name
director.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
director.head(12)
# Out:
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# 5        Andrew Stanton
# 6             Sam Raimi
# 7          Nathan Greno
# 8           Joss Whedon
# 9           David Yates
# 10          Zack Snyder
# 11         Bryan Singer
# Name: director_name, dtype: object

# %%
director.value_counts().head(12)
# Out:
# Steven Spielberg     26
# Woody Allen          22
# Clint Eastwood       20
# Martin Scorsese      20
# Spike Lee            16
# Ridley Scott         16
# Renny Harlin         15
# Steven Soderbergh    15
# Oliver Stone         14
# Tim Burton           14
# Robert Rodriguez     13
# Joel Schumacher      13
# Name: director_name, dtype: int64

# %%
director.size
# Out:
# 4916

# %%
director.shape
# Out:
# (4916,)

# %%
len(director)
# Out:
# 4916

# %%
director.count()
# Out:
# 4814

# %%
director.isnull().sum()
# Out:
# 102

# %%
director.size - director.isnull().sum() # This is basically the output generated by Count() menthod
# Out:
# 4814

# %%
director.notnull().sum()

# %%
actor_1_facebook_likes = movie.actor_1_facebook_likes
actor_1_facebook_likes.head()
# Out:
# 0     1000.0
# 1    40000.0
# 2    11000.0
# 3    27000.0
# 4      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
actor_1_facebook_likes.mean(), \
actor_1_facebook_likes.median(), \
actor_1_facebook_likes.max(), \
actor_1_facebook_likes.mode(), \
actor_1_facebook_likes.min(), \
actor_1_facebook_likes.std(), \
actor_1_facebook_likes.sum()
# Out:
# (6494.488490527602,
#  982.0,
#  640000.0,
#  0    1000.0
#  dtype: float64,
#  0.0,
#  15106.986883848309,
#  31881444.0)

# %%
actor_1_facebook_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
actor_1_facebook_likes.quantile()
# Out:
# 982.0

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("IFKQLDmRK0Y")

# %%
actor_1_facebook_likes.quantile([0.2, 0.6, 0.8])
# Out:
# 0.2      510.0
# 0.6     1000.0
# 0.8    13000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
actor_1_facebook_likes.count(), actor_1_facebook_likes.size
# Out:
# (4909, 4916)

# %%
actor_1_facebook_likes.isnull().sum()
# Out:
# 7

# %%
actor_1_facebook_likes_filled = actor_1_facebook_likes.fillna(0)
actor_1_facebook_likes_filled.count()
# Out:
# 4916

# %%
actor_1_facebook_likes_dropped = actor_1_facebook_likes.dropna()
actor_1_facebook_likes_dropped.count()
# Out:
# 4909

# %%
director.hasnans
# Out:
# True

# %%
actor_1_facebook_likes.hasnans
# Out:
# True

# %%
actor_1_facebook_likes_filled.hasnans
# Out:
# False

# %%
movie_actor_director = movie[['actor_1_name', 'actor_2_name', 'actor_3_name']]
movie_actor_director
# Out:
#          actor_1_name      actor_2_name          actor_3_name
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
# [4916 rows x 3 columns]

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie.filter(['actor_1_name', 'actor_2_name', 'actor_3_name'])
# Out:
#          actor_1_name      actor_2_name          actor_3_name
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
# [4916 rows x 3 columns]

# %%
movie.filter(regex = '[Aa]')
# Out:
#           director_name  duration  director_facebook_likes  \
# 0         James Cameron     178.0                      0.0
# 1        Gore Verbinski     169.0                    563.0
# 2            Sam Mendes     148.0                      0.0
# 3     Christopher Nolan     164.0                  22000.0
# 4           Doug Walker       NaN                    131.0
# ...                 ...       ...                      ...
# 4911        Scott Smith      87.0                      2.0
# 4912                NaN      43.0                      NaN
# 4913   Benjamin Roberds      76.0                      0.0
# 4914        Daniel Hsia     100.0                      0.0
# 4915           Jon Gunn      90.0                     16.0
#
#       actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                      855.0  Joel David Moore                  1000.0
# 1                     1000.0     Orlando Bloom                 40000.0
# ...

# %%
movie.select_dtypes(include = 'float64')
# Out:
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 0                      723.0     178.0                      0.0
# 1                      302.0     169.0                    563.0
# 2                      602.0     148.0                      0.0
# 3                      813.0     164.0                  22000.0
# 4                        NaN       NaN                    131.0
# ...                      ...       ...                      ...
# 4911                     1.0      87.0                      2.0
# 4912                    43.0      43.0                      NaN
# 4913                    13.0      76.0                      0.0
# 4914                    14.0     100.0                      0.0
# 4915                    43.0      90.0                     16.0
#
#       actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                      855.0                  1000.0  760505847.0
# ...

# %%
movie.shape
# Out:
# (4916, 28)

# %%
movie.size #returns the total no of elements in the df
# Out:
# 137648

# %%
movie.count() #returns the number of non missing values in each columns
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
len(movie) # returns the no of rows
# Out:
# 4916

# %%
movie.ndim
# Out:
# 2

# %%
movie.min()
# Out:
# num_critic_for_reviews                                                       1
# duration                                                                     7
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                       0
# actor_1_facebook_likes                                                       0
# gross                                                                      162
# genres                                                                  Action
# movie_title                                                            #Horror
# num_voted_users                                                              5
# cast_total_facebook_likes                                                    0
# facenumber_in_poster                                                         0
# movie_imdb_link              http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# ...

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie.describe().shape
# Out:
# (8, 16)

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie.notnull().sum()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
movie.isnull().sum().sum()
# Out:
# 2654

# %%
movie + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# E:\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# E:\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# E:\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
movie > 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-16195244cafb> in <module>
# ----> 1 movie > 5
#
# E:\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     850             # straight boolean comparisons we want to allow all columns
#     851             # (regardless of dtype to pass thru) See #4537 for discussion.
# --> 852             new_data = dispatch_to_series(self, other, op)
#     853             return self._construct_result(new_data)
#     854
#
# E:\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     379         # Get the appropriate array-op to apply to each block's values.
#     380         array_op = get_array_op(func, str_rep=str_rep)
# --> 381         bm = left._data.apply(array_op, right=right)
#     382         return type(left)(bm)
#     383
#
# ...

# %%
np.nan == np.nan
# Out:
# False

# %%
True == True
# Out:
# True

# %%
movie == movie
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0      True           True                    True      True
# 1      True           True                    True      True
# 2      True           True                    True      True
# 3      True           True                    True      True
# 4     False           True                   False     False
# ...     ...            ...                     ...       ...
# 4911   True           True                    True      True
# 4912   True          False                    True      True
# 4913   True           True                    True      True
# 4914   True           True                    True      True
# 4915   True           True                    True      True
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                        True                    True          True
# 1                        True                    True          True
# ...

# %%
(movie == movie).all()
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews       False
# duration                     False
# director_facebook_likes      False
# actor_3_facebook_likes       False
# actor_2_name                 False
# actor_1_facebook_likes       False
# gross                        False
# genres                        True
# actor_1_name                 False
# movie_title                   True
# num_voted_users               True
# cast_total_facebook_likes     True
# actor_3_name                 False
# facenumber_in_poster         False
# plot_keywords                False
# movie_imdb_link               True
# num_user_for_reviews         False
# language                     False
# country                      False
# content_rating               False
# budget                       False
# title_year                   False
# actor_2_facebook_likes       False
# imdb_score                    True
# aspect_ratio                 False
# ...

# %%
(movie == movie).all().all()
# Out:
# False

# %%
(movie == np.nan).sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie.isna().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie.equals(movie)
# Out:
# True

# %%
movie.count()#calculates on axis=0
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
movie.count(axis = 1)
# Out:
# 0       28
# 1       28
# 2       28
# 3       28
# 4       14
#         ..
# 4911    24
# 4912    23
# 4913    24
# 4914    26
# 4915    28
# Length: 4916, dtype: int64

# %%
movie.sum(axis = 1)
# Out:
# 0       9.984386e+08
# 1       6.099740e+08
# 2       4.454621e+08
# 3       6.996464e+08
# 4       4.321000e+02
#             ...
# 4911    6.539700e+03
# 4912    1.098145e+05
# 4913    3.565300e+03
# 4914    1.904665e+04
# 4915    9.359645e+04
# Length: 4916, dtype: float64

# %%
#Adding new cols to the DF
#1. by assigning a scalar value
movie['Has Seen'] = 'Yes'
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
#combining several cols
movie['combined_fb_likes'] = (movie['actor_1_facebook_likes']+
                             movie['actor_2_facebook_likes']+
                             movie['actor_3_facebook_likes']+
                             movie['director_facebook_likes'])
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie['is_cas_likes_more'] = (movie['cast_total_facebook_likes'] >= movie['combined_fb_likes'])
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
5 >np.nan
# Out:
# False

# %%
5 < np.nan
# Out:
# False

# %%
movie.drop('Has Seen')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-e6b9cd0e96f7> in <module>
# ----> 1 movie.drop('Has Seen')
#
# E:\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# E:\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# E:\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
movie.drop('Has Seen', axis=1)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
del(movie['Has Seen'])

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...
