# %%
import pandas as pd
import numpy as np

# %%
so = pd.read_csv('data/stackoverflow_qa.csv')
head = pd.read_csv('data/stackoverflow_qa.csv').head()
so.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %%
so.shape
# Out:
# (56398, 12)

# %%
so_head = so.head()
so_head
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %%
#Manually create the list of booleans
criteria = [True, False, True, False, False]
so_head.loc[criteria]
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 2  5558607  2011-04-05 21:13:50      2       7392
#
#                                          title  answercount  commentcount  \
# 0                     Rolling median in python            3             4
# 2  Sort a pandas DataMatrix in ascending order            2             0
#
#    favoritecount      quest_name  quest_rep         ans_name  ans_rep
# 0            1.0         yueerhu      125.0  Mike Pennington  26995.0
# 2            1.0  Jason Strimpel     3301.0     Wes McKinney  43310.0

# %%
# Using numpy arrays
arr = np.array([True, False, False, False, True])
so_head.loc[arr]
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount    quest_name  quest_rep         ans_name  \
# 0             4            1.0       yueerhu      125.0  Mike Pennington
# 4             0            5.0  Uri Laserson      958.0             HYRY
#
#    ans_rep
# 0  26995.0
# 4  54137.0

# %%
c1 = [True, False, True]*4
c1
# Out:
# [True, False, True, True, False, True, True, False, True, True, False, True]

# %%
so_head.loc[:, c1] #Column number should be of exact length
# Out:
#         id  score  viewcount  answercount  commentcount      quest_name  \
# 0  5486226      4       2113            3             4         yueerhu
# 1  5515021      8       7015            3             6  Jason Strimpel
# 2  5558607      2       7392            2             0  Jason Strimpel
# 3  6467832      9      13056            1             0      user814005
# 4  7577546      9       2488            1             0    Uri Laserson
#
#    quest_rep  ans_rep
# 0      125.0  26995.0
# 1     3301.0  26995.0
# 2     3301.0  43310.0
# 3      117.0  43310.0
# 4      958.0  54137.0

# %%
c2 = [True, False, True]*3
c2
# Out:
# [True, False, True, True, False, True, True, False, True]

# %%
so_head.loc[:, c2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-ab2c96f3a7e0> in <module>
# ----> 1 so_head.loc[:, c2]
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1912             return self._get_slice_axis(key, axis=axis)
# ...

# %%
s = pd.Series([True, True, False, False, False])
s
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
so_head[s]
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
#
#                                           title  answercount  commentcount  \
# 0                      Rolling median in python            3             4
# 1  Compute a compounded return series in Python            3             6
#
#    favoritecount      quest_name  quest_rep         ans_name  ans_rep
# 0            1.0         yueerhu      125.0  Mike Pennington  26995.0
# 1            7.0  Jason Strimpel     3301.0  Mike Pennington  26995.0

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
so_head.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
head = so_head.set_index('id', inplace=True)
head
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-c93f09d9a78b> in <module>
# ----> 1 head = so_head.set_index('id', inplace=True)
#       2 head
#
# E:\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['id'] are in the columns"

# %%
head
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %%
head.set_index('id', inplace = True)
head
# Out:
#                 creationdate  score  viewcount  \
# id
# 5486226  2011-03-30 12:26:50      4       2113
# 5515021  2011-04-01 14:50:44      8       7015
# 5558607  2011-04-05 21:13:50      2       7392
# 6467832  2011-06-24 12:31:45      9      13056
# 7577546  2011-09-28 01:58:38      9       2488
#
#                                                      title  answercount  \
# id
# 5486226                           Rolling median in python            3
# 5515021       Compute a compounded return series in Python            3
# 5558607        Sort a pandas DataMatrix in ascending order            2
# 6467832  How to get the correlation between two timeser...            1
# 7577546  Using pandas, how do I subsample a large DataF...            1
#
#          commentcount  favoritecount      quest_name  quest_rep  \
# id
# 5486226             4            1.0         yueerhu      125.0
# 5515021             6            7.0  Jason Strimpel     3301.0
# ...

# %%
head[s]
# Out:
# <ipython-input-37-8f07cd976730>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   head[s]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-37-8f07cd976730> in <module>
# ----> 1 head[s]
#
# E:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# E:\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2841         # check_bool_indexer will throw exception if Series key cannot
#    2842         # be reindexed to match DataFrame rows
# -> 2843         key = check_bool_indexer(self.index, key)
# ...

# %%
so.loc[:, 'score'] > 10
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: score, Length: 56398, dtype: bool

# %%
criteria = so['score'] >=10
criteria.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# Name: score, dtype: bool

# %%
so.loc[criteria].head()
# Out:
#          id         creationdate  score  viewcount  \
# 6   7776679  2011-10-15 08:21:17     25      28159
# 7   7813132  2011-10-18 20:16:12     10      18917
# 8   7837722  2011-10-20 14:46:14    201     223746
# 14  8916302  2012-01-18 19:41:27     29      20614
# 17  8991709  2012-01-24 17:59:53    136      16783
#
#                                                 title  answercount  \
# 6                   append two data frame with pandas            2
# 7   Convert array of string (category) to array of...            3
# 8   What is the most efficient way to loop through...            8
# 14  selecting across multiple columns with python ...            3
# 17  Why are pandas merges in python faster than da...            3
#
#     commentcount  favoritecount      quest_name  quest_rep       ans_name  \
# 6              7            4.0        Jean-Pat      882.0   Wes McKinney
# 7              0            6.0        Jean-Pat      882.0   Wes McKinney
# ...

# %%
so_score_10_or_more = so.loc[criteria].head()
so_score_10_or_more
# Out:
#          id         creationdate  score  viewcount  \
# 6   7776679  2011-10-15 08:21:17     25      28159
# 7   7813132  2011-10-18 20:16:12     10      18917
# 8   7837722  2011-10-20 14:46:14    201     223746
# 14  8916302  2012-01-18 19:41:27     29      20614
# 17  8991709  2012-01-24 17:59:53    136      16783
#
#                                                 title  answercount  \
# 6                   append two data frame with pandas            2
# 7   Convert array of string (category) to array of...            3
# 8   What is the most efficient way to loop through...            8
# 14  selecting across multiple columns with python ...            3
# 17  Why are pandas merges in python faster than da...            3
#
#     commentcount  favoritecount      quest_name  quest_rep       ans_name  \
# 6              7            4.0        Jean-Pat      882.0   Wes McKinney
# 7              0            6.0        Jean-Pat      882.0   Wes McKinney
# ...

# %%
so[so['score'] >= 10].head()
# Out:
#          id         creationdate  score  viewcount  \
# 6   7776679  2011-10-15 08:21:17     25      28159
# 7   7813132  2011-10-18 20:16:12     10      18917
# 8   7837722  2011-10-20 14:46:14    201     223746
# 14  8916302  2012-01-18 19:41:27     29      20614
# 17  8991709  2012-01-24 17:59:53    136      16783
#
#                                                 title  answercount  \
# 6                   append two data frame with pandas            2
# 7   Convert array of string (category) to array of...            3
# 8   What is the most efficient way to loop through...            8
# 14  selecting across multiple columns with python ...            3
# 17  Why are pandas merges in python faster than da...            3
#
#     commentcount  favoritecount      quest_name  quest_rep       ans_name  \
# 6              7            4.0        Jean-Pat      882.0   Wes McKinney
# 7              0            6.0        Jean-Pat      882.0   Wes McKinney
# ...

# %%
#step 1 is to crate a boolean series
criteria = so['ans_name'] == 'Scott Boston'

#step 2 do a boolean selection
so[criteria].head()
# Out:
#              id         creationdate  score  viewcount  \
# 38161  43491342  2017-04-19 09:14:28      4        167
# 38178  43190850  2017-04-03 17:31:33      1        284
# 38237  43176052  2017-04-03 03:21:12      2         39
# 38246  43209525  2017-04-04 14:03:17      5        131
# 38275  43211893  2017-04-04 15:45:17      0         38
#
#                                                    title  answercount  \
# 38161  Merging pandas dataframes based on nearest val...            1
# 38178                     Python Seaborn Plot ValueError            2
# 38237  Convert an indexed pandas matrix to a flat dat...            2
# 38246          Pandas: Optimal way to MultiIndex columns            2
# 38275  How to calculate a index series for a event wi...            1
#
#        commentcount  favoritecount    quest_name  quest_rep      ans_name  \
# 38161             0            NaN       AkiRoss     3991.0  Scott Boston
# ...

# %%
score_5 = so.tail()['score'] > 5
score_5
# Out:
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: score, dtype: bool

# %%
(so.tail()['score'] > 5) & (so.tail()['score'] <= 8)
# Out:
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: score, dtype: bool

# %%
criteria1 = so['score'] >= 5
criteria2 = so['ans_name'] == 'Scott Boston'

# %%
crtieria_all = criteria1 & criteria2

# %%
so[crtieria_all].head()
# Out:
#              id         creationdate  score  viewcount  \
# 38246  43209525  2017-04-04 14:03:17      5        131
# 38640  42870703  2017-03-18 05:06:22      5        125
# 44358  45064916  2017-07-12 18:16:49      5        428
# 44814  44877663  2017-07-03 04:07:59      9       1267
# 52013  47061564  2017-11-01 18:40:36      5         60
#
#                                                    title  answercount  \
# 38246          Pandas: Optimal way to MultiIndex columns            2
# 38640  Simultaneous operation of groupby and resample...            1
# 44358  How to find the correlation between a group of...            2
# 44814       Error: float object has no attribute notnull            3
# 52013  How to create strings from dataframe columns e...            5
#
#        commentcount  favoritecount    quest_name  quest_rep      ans_name  \
# 38246             0            0.0  sparc_spread     5470.0  Scott Boston
# ...

# %%
so[(so['score'] >= 5) & (so['ans_name'] == 'Scott Boston')].head()
# Out:
#              id         creationdate  score  viewcount  \
# 38246  43209525  2017-04-04 14:03:17      5        131
# 38640  42870703  2017-03-18 05:06:22      5        125
# 44358  45064916  2017-07-12 18:16:49      5        428
# 44814  44877663  2017-07-03 04:07:59      9       1267
# 52013  47061564  2017-11-01 18:40:36      5         60
#
#                                                    title  answercount  \
# 38246          Pandas: Optimal way to MultiIndex columns            2
# 38640  Simultaneous operation of groupby and resample...            1
# 44358  How to find the correlation between a group of...            2
# 44814       Error: float object has no attribute notnull            3
# 52013  How to create strings from dataframe columns e...            5
#
#        commentcount  favoritecount    quest_name  quest_rep      ans_name  \
# 38246             0            0.0  sparc_spread     5470.0  Scott Boston
# ...

# %%
so[(so['score'] >= 5) | (so['ans_name'] == 'Scott Boston')].head()
# Out:
#         id         creationdate  score  viewcount  \
# 1  5515021  2011-04-01 14:50:44      8       7015
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
# 6  7776679  2011-10-15 08:21:17     25      28159
# 7  7813132  2011-10-18 20:16:12     10      18917
#
#                                                title  answercount  \
# 1       Compute a compounded return series in Python            3
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
# 6                  append two data frame with pandas            2
# 7  Convert array of string (category) to array of...            3
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# 3             0            7.0      user814005      117.0     Wes McKinney
# ...

# %%
so[~(so['score'] <= 100)].head()
# Out:
#            id         creationdate  score  viewcount  \
# 8     7837722  2011-10-20 14:46:14    201     223746
# 17    8991709  2012-01-24 17:59:53    136      16783
# 75   10373660  2012-04-29 16:10:35    199     207980
# 100  10665889  2012-05-19 14:11:42    144     179896
# 106  10715965  2012-05-23 08:12:31    340     408347
#
#                                                  title  answercount  \
# 8    What is the most efficient way to loop through...            8
# 17   Why are pandas merges in python faster than da...            3
# 75     Converting a Pandas GroupBy object to DataFrame            5
# 100   How to take column-slices of dataframe in pandas            7
# 106                  add one row in a pandas.DataFrame           15
#
#      commentcount  favoritecount quest_name  quest_rep       ans_name  ans_rep
# 8               3          115.0     Muppet     1563.0  Nick Crawford   2779.0
# ...

# %%
criteria1 = (so['ans_name'] == 'Scott Boston') & (so['score'] >= 5)
criteria2 = (so['ans_name'] == 'Ted Petrou') & (so['answercount'] >= 5)
final_criteria = criteria1 | criteria2
so[final_criteria].head()
# Out:
#              id         creationdate  score  viewcount  \
# 100    10665889  2012-05-19 14:11:42    144     179896
# 38246  43209525  2017-04-04 14:03:17      5        131
# 38640  42870703  2017-03-18 05:06:22      5        125
# 44358  45064916  2017-07-12 18:16:49      5        428
# 44814  44877663  2017-07-03 04:07:59      9       1267
#
#                                                    title  answercount  \
# 100     How to take column-slices of dataframe in pandas            7
# 38246          Pandas: Optimal way to MultiIndex columns            2
# 38640  Simultaneous operation of groupby and resample...            1
# 44358  How to find the correlation between a group of...            2
# 44814       Error: float object has no attribute notnull            3
#
#        commentcount  favoritecount    quest_name  quest_rep      ans_name  \
# 100               3           65.0           cpa      988.0    Ted Petrou
# ...

# %%
criteria = so['ans_name'].isin(['Scott Boston', 'Ted Petrou', 'MaxU', 'unutbu'])

# %%
criteria.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: ans_name, dtype: bool

# %%
so[criteria].head()
# Out:
#            id         creationdate  score  viewcount  \
# 100  10665889  2012-05-19 14:11:42    144     179896
# 574  13385860  2012-11-14 19:25:28     29      31712
# 593  13446480  2012-11-19 01:20:07     18       7969
# 599  13460889  2012-11-19 19:39:06      8       3168
# 639  13653030  2012-11-30 20:54:35      6      11798
#
#                                                  title  answercount  \
# 100   How to take column-slices of dataframe in pandas            7
# 574  How can I remove extra whitespace from strings...            6
# 593  Python Pandas: remove entries based on the num...            4
# 599  How to redirect all methods of a contained cla...            2
# 639  How do I Pass a List of Series to a Pandas Dat...            5
#
#      commentcount  favoritecount quest_name  quest_rep    ans_name   ans_rep
# 100             3           65.0        cpa      988.0  Ted Petrou   10426.0
# 574             0           17.0      mpjan      530.0      unutbu  464745.0
# ...

# %%
criteria_1 = so['ans_name'].isin(['Scott Boston', 'Ted Petrou', 'MaxU', 'unutbu'])
criteria_2 = so['score'] > 30
criteria_all = criteria_1 & criteria_2
so[criteria_all].tail()
# Out:
#              id         creationdate  score  viewcount  \
# 4389   21800169  2014-02-15 16:18:11     81     183564
# 5179   21415661  2014-01-28 20:04:04     38      46056
# 7411   25254016  2014-08-11 23:30:16     73     113632
# 11136  29370057  2015-03-31 13:38:06     51      72821
# 25710  38250710  2016-07-07 16:26:26     47      20477
#
#                                                    title  answercount  \
# 4389   Python Pandas: Get index of rows which column ...            2
# 5179       Logic operator for boolean indexing in Pandas            1
# 7411      Pandas - Get first row value of a given column            4
# 11136            Select dataframe rows between two dates            4
# 25710  How to split data into 3 sets (train, validati...            3
#
#        commentcount  favoritecount     quest_name  quest_rep ans_name  \
# 4389              0           40.0  I want badges      708.0   unutbu
# ...

# %%
no_ans = so['ans_name'].isnull()
no_ans
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56393    False
# 56394     True
# 56395     True
# 56396    False
# 56397     True
# Name: ans_name, Length: 56398, dtype: bool

# %%
so[no_ans].head()
# Out:
#          id         creationdate  score  viewcount  \
# 5   7766400  2011-10-14 10:33:54      2        977
# 11  8451327  2011-12-09 20:27:24      1       2435
# 16  8966871  2012-01-23 03:21:00      0        287
# 29  9641916  2012-03-09 22:36:52      7       5519
# 30  9647656  2012-03-10 15:35:26      3        986
#
#                                                 title  answercount  \
# 5             Pandas + Django + mod_wsgi + virtualenv            1
# 11  Python map() function output into Pandas DataF...            1
# 16  Running Python/Numpy/Pandas on older secure co...            0
# 29  Python Pandas: can't find numpy.core.multiarra...            4
# 30  Pandas dataframe in mixed mode can't serialize...            1
#
#     commentcount  favoritecount           quest_name  quest_rep ans_name  \
# 5              2            1.0           Evan Davey      100.0      NaN
# 11             0            1.0             briant57        6.0      NaN
# ...

# %%
s = so['commentcount']
s
# Out:
# 0        4
# 1        6
# 2        0
# 3        0
# 4        0
#         ..
# 56393    1
# 56394    2
# 56395    4
# 56396    0
# 56397    0
# Name: commentcount, Length: 56398, dtype: int64

# %%
criteria = s > 10
criteria
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56393    False
# 56394    False
# 56395    False
# 56396    False
# 56397    False
# Name: commentcount, Length: 56398, dtype: bool

# %%
s[criteria].head()
# Out:
# 17     16
# 76     14
# 566    11
# 763    12
# 781    19
# Name: commentcount, dtype: int64

# %%
s[s > 10].head()
# Out:
# 17     16
# 76     14
# 566    11
# 763    12
# 781    19
# Name: commentcount, dtype: int64

# %%
s[(s > 10) & (s < 15)].head()
# Out:
# 76     14
# 566    11
# 763    12
# 787    12
# 837    13
# Name: commentcount, dtype: int64

# %%
s[s.between(11, 14)].head() # 11 and 14 includedb
# Out:
# 76     14
# 566    11
# 763    12
# 787    12
# 837    13
# Name: commentcount, dtype: int64

# %%
so.loc[(so['score'] > 5)].head()
# Out:
#         id         creationdate  score  viewcount  \
# 1  5515021  2011-04-01 14:50:44      8       7015
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
# 6  7776679  2011-10-15 08:21:17     25      28159
# 7  7813132  2011-10-18 20:16:12     10      18917
#
#                                                title  answercount  \
# 1       Compute a compounded return series in Python            3
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
# 6                  append two data frame with pandas            2
# 7  Convert array of string (category) to array of...            3
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# 3             0            7.0      user814005      117.0     Wes McKinney
# ...

# %%
so.loc[(so['score'] > 5), ['ans_name', 'ans_rep']].head()
# Out:
#           ans_name  ans_rep
# 1  Mike Pennington  26995.0
# 3     Wes McKinney  43310.0
# 4             HYRY  54137.0
# 6     Wes McKinney  43310.0
# 7     Wes McKinney  43310.0

# %%
so.loc[so.loc[:, 'favoritecount'].between(30, 40), 'title'::2].head()
# Out:
#                                                  title  commentcount  \
# 348  Pandas: create two new columns in a dataframe ...             0
# 555  How can I replace all the NaN values with Zero...             1
# 643  Pandas DataFrame: remove unwanted parts from s...             1
# 667  Creating an empty Pandas DataFrame, then filli...             0
# 892  Apply multiple functions to multiple groupby c...             1
#
#           quest_name     ans_name
# 348          joaquin          DSM
# 555  George Thompson         Aman
# 643      Yannan Wang       eumiro
# 667   Matthias Kauer  Andy Hayden
# 892           beardc     Zelazny7

# %%
col_bools = [True, False, True] * 4
so.loc[:, col_bools]
# Out:
#              id  score  viewcount  answercount  commentcount      quest_name  \
# 0       5486226      4       2113            3             4         yueerhu
# 1       5515021      8       7015            3             6  Jason Strimpel
# 2       5558607      2       7392            2             0  Jason Strimpel
# 3       6467832      9      13056            1             0      user814005
# 4       7577546      9       2488            1             0    Uri Laserson
# ...         ...    ...        ...          ...           ...             ...
# 56393  47606711      0         17            1             1            xxyy
# 56394  47607549     -1         41            1             2           Ajeet
# 56395  47609325      0         33            2             4            NthA
# 56396  47609598      2         18            1             0         Fan LUO
# 56397  47611969     -6         19            0             0   Soorya Paturi
#
#        quest_rep  ans_rep
# ...

# %%
criteria = so['score'] > so['commentcount']
so[criteria].head()
# Out:
#         id         creationdate  score  viewcount  \
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
# 6  7776679  2011-10-15 08:21:17     25      28159
#
#                                                title  answercount  \
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
# 6                  append two data frame with pandas            2
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# 2             0            1.0  Jason Strimpel     3301.0     Wes McKinney
# ...

# %%
so.iloc[so['viewcount'] > 100000]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-87-87e495d37c8d> in <module>
# ----> 1 so.iloc[so['viewcount'] > 100000]
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2122
#    2123         if com.is_bool_indexer(key):
# -> 2124             self._validate_key(key, axis)
#    2125             return self._getbool_axis(key, axis=axis)
#    2126
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...
