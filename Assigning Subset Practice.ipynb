# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/employee_sample.csv', index_col = 0)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565

# %%
# New column by assigning a scalar value
df['SCORE'] = 99
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99

# %%
df['BONUS RATE'] = [0.2, 0.5, 0.9, 0.2, 0.4, 0.7, 0.3]
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE
# Tom              0.2
# Niko             0.5
# Penelope         0.9
# Aria             0.2
# Sofia            0.4
# Dean             0.7
# Zach             0.3

# %%
df['FLOOR'] = np.random.randint(low = 0, high = 10, size = len(df))
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR
# Tom              0.2      0
# Niko             0.5      0
# Penelope         0.9      8
# Aria             0.2      6
# Sofia            0.4      4
# Dean             0.7      4
# Zach             0.3      8

# %%
last_name = pd.Series(['Smit', 'Archer', 'Rbada', 'Pattinson', 'Norte'])
last_name
# Out:
# 0         Smit
# 1       Archer
# 2        Rbada
# 3    Pattinson
# 4        Norte
# dtype: object

# %%
df['LAST NAME'] = last_name
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR LAST NAME
# Tom              0.2      0       NaN
# Niko             0.5      0       NaN
# Penelope         0.9      8       NaN
# Aria             0.2      6       NaN
# Sofia            0.4      4       NaN
# Dean             0.7      4       NaN
# Zach             0.3      8       NaN

# %%
last_name.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index
# Out:
# Index(['Tom', 'Niko', 'Penelope', 'Aria', 'Sofia', 'Dean', 'Zach'], dtype='object')

# %%
last_name.index = df.index[:len(last_name)]
last_name
# Out:
# Tom              Smit
# Niko           Archer
# Penelope        Rbada
# Aria        Pattinson
# Sofia           Norte
# dtype: object

# %%
df['LAST NAME'] = last_name
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR  LAST NAME
# Tom              0.2      0       Smit
# Niko             0.5      0     Archer
# Penelope         0.9      8      Rbada
# Aria             0.2      6  Pattinson
# Sofia            0.4      4      Norte
# Dean             0.7      4        NaN
# Zach             0.3      8        NaN

# %%
last_name = pd.Series(['Smit', 'Archer', 'Rbada', 'Pattinson', 'Norte'])
df['last name'] = last_name

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR  LAST NAME last name
# Tom              0.2      0       Smit       NaN
# Niko             0.5      0     Archer       NaN
# Penelope         0.9      8      Rbada       NaN
# Aria             0.2      6  Pattinson       NaN
# Sofia            0.4      4      Norte       NaN
# Dean             0.7      4        NaN       NaN
# ...

# %%
last_name = pd.Series(['Smit', 'Archer', 'Rbada', 'Pattinson', 'Norte', 'Fergusson', 'Boult'], index = df.index)
df['LAST NAME'] = last_name
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR  LAST NAME last name
# Tom              0.2      0       Smit       NaN
# Niko             0.5      0     Archer       NaN
# Penelope         0.9      8      Rbada       NaN
# Aria             0.2      6  Pattinson       NaN
# Sofia            0.4      4      Norte       NaN
# Dean             0.7      4  Fergusson       NaN
# ...

# %%
df['BONUS RATE'] * df['SALARY']
# Out:
# Tom         21592.4
# Niko        15173.5
# Penelope    54232.2
# Aria         8723.6
# Sofia       10450.0
# Dean        23514.4
# Zach        11269.5
# dtype: float64

# %%
df['BONUS'] = df['BONUS RATE'] * df['SALARY']
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99
#
#           BONUS RATE  FLOOR  LAST NAME last name    BONUS
# Tom              0.2      0       Smit       NaN  21592.4
# Niko             0.5      0     Archer       NaN  15173.5
# Penelope         0.9      8      Rbada       NaN  54232.2
# Aria             0.2      6  Pattinson       NaN   8723.6
# Sofia            0.4      4      Norte       NaN  10450.0
# ...

# %%
df['SCORE'] = 100
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR  LAST NAME last name    BONUS
# Tom              0.2      0       Smit       NaN  21592.4
# Niko             0.5      0     Archer       NaN  15173.5
# Penelope         0.9      8      Rbada       NaN  54232.2
# Aria             0.2      6  Pattinson       NaN   8723.6
# Sofia            0.4      4      Norte       NaN  10450.0
# ...

# %%
df['BONUS'] = df['BONUS'].astype(int)
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      0       Smit       NaN  21592
# Niko             0.5      0     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df.loc[['Tom', 'Niko', 'Dean'], ['FLOOR']]
# Out:
#       FLOOR
# Tom       0
# Niko      0
# Dean      4

# %%
df.loc[['Tom', 'Niko', 'Dean'], ['FLOOR']] = [7, 8, 3]
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258    100
# Aria      Female  Black         Engineering                 8   43618    100
# Sofia     Female  Black  Parks & Recreation                23   26125    100
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  21592
# Niko             0.5      8     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df.iloc[2:5, 5] = 99
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  21592
# Niko             0.5      8     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df_selected = df[['GENDER', 'YEARS EXPERIENCE', 'SCORE']].copy()
df_selected
# Out:
#           GENDER  YEARS EXPERIENCE  SCORE
# Tom         Male                23    100
# Niko        Male                 1    100
# Penelope  Female                12     99
# Aria      Female                 8     99
# Sofia     Female                23     99
# Dean        Male                 3    100
# Zach        Male                 4    100

# %%
df_selected.loc[df_selected['YEARS EXPERIENCE'] > 20, 'SCORE'] = 75
df_selected
# Out:
#           GENDER  YEARS EXPERIENCE  SCORE
# Tom         Male                23     75
# Niko        Male                 1    100
# Penelope  Female                12     99
# Aria      Female                 8     99
# Sofia     Female                23     75
# Dean        Male                 3    100
# Zach        Male                 4    100

# %%
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962    100
# Niko        Male  Black         Engineering                 1   30347    100
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592    100
# Zach        Male  White  Parks & Recreation                 4   37565    100
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  21592
# Niko             0.5      8     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df_orig = df.copy()
df.loc[:, 'SCORE'] = 33
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     33
# Niko        Male  Black         Engineering                 1   30347     33
# Penelope  Female  White         Engineering                12   60258     33
# Aria      Female  Black         Engineering                 8   43618     33
# Sofia     Female  Black  Parks & Recreation                23   26125     33
# Dean        Male  Black  Parks & Recreation                 3   33592     33
# Zach        Male  White  Parks & Recreation                 4   37565     33
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  21592
# Niko             0.5      8     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df_orig = df.copy()
df.iloc[:, 5] = 45
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     45
# Niko        Male  Black         Engineering                 1   30347     45
# Penelope  Female  White         Engineering                12   60258     45
# Aria      Female  Black         Engineering                 8   43618     45
# Sofia     Female  Black  Parks & Recreation                23   26125     45
# Dean        Male  Black  Parks & Recreation                 3   33592     45
# Zach        Male  White  Parks & Recreation                 4   37565     45
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  21592
# Niko             0.5      8     Archer       NaN  15173
# Penelope         0.9      8      Rbada       NaN  54232
# Aria             0.2      6  Pattinson       NaN   8723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
df.loc[df['DEPARTMENT'] == 'Engineering', 'BONUS']
# Out:
# Tom         21592
# Niko        15173
# Penelope    54232
# Aria         8723
# Name: BONUS, dtype: int32

# %%
df.loc[df['DEPARTMENT'] == 'Engineering', 'BONUS'] += 5000
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     45
# Niko        Male  Black         Engineering                 1   30347     45
# Penelope  Female  White         Engineering                12   60258     45
# Aria      Female  Black         Engineering                 8   43618     45
# Sofia     Female  Black  Parks & Recreation                23   26125     45
# Dean        Male  Black  Parks & Recreation                 3   33592     45
# Zach        Male  White  Parks & Recreation                 4   37565     45
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  46592
# Niko             0.5      8     Archer       NaN  40173
# Penelope         0.9      8      Rbada       NaN  79232
# Aria             0.2      6  Pattinson       NaN  33723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
white_male = (df['GENDER'] == 'Male') & (df['RACE'] == 'White')
black_female = (df['GENDER'] == 'Female') & (df['RACE'] == 'Black')
criteria = white_male | black_female
df[criteria]
# Out:
#        GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom      Male  White         Engineering                23  107962     45
# Aria   Female  Black         Engineering                 8   43618     45
# Sofia  Female  Black  Parks & Recreation                23   26125     45
# Zach     Male  White  Parks & Recreation                 4   37565     45
#
#        BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom           0.2      7       Smit       NaN  46592
# Aria          0.2      6  Pattinson       NaN  33723
# Sofia         0.4      4      Norte       NaN  10450
# Zach          0.3      8      Boult       NaN  11269

# %%
df.loc[criteria, 'SCORE'] -= 10
df
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE  \
# Tom         Male  White         Engineering                23  107962     25
# Niko        Male  Black         Engineering                 1   30347     45
# Penelope  Female  White         Engineering                12   60258     45
# Aria      Female  Black         Engineering                 8   43618     25
# Sofia     Female  Black  Parks & Recreation                23   26125     25
# Dean        Male  Black  Parks & Recreation                 3   33592     45
# Zach        Male  White  Parks & Recreation                 4   37565     25
#
#           BONUS RATE  FLOOR  LAST NAME last name  BONUS
# Tom              0.2      7       Smit       NaN  46592
# Niko             0.5      8     Archer       NaN  40173
# Penelope         0.9      8      Rbada       NaN  79232
# Aria             0.2      6  Pattinson       NaN  33723
# Sofia            0.4      4      Norte       NaN  10450
# ...

# %%
s = df['SALARY']
s
# Out:
# Tom         107962
# Niko         30347
# Penelope     60258
# Aria         43618
# Sofia        26125
# Dean         33592
# Zach         37565
# Name: SALARY, dtype: int64

# %%
s.loc[['Tom', 'Niko', 'Dean']] = [3000, 4000, 5000]
s
# Out:
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# Tom          3000
# Niko         4000
# Penelope    60258
# Aria        43618
# Sofia       26125
# Dean         5000
# Zach        37565
# Name: SALARY, dtype: int64

# %%
s = df['SALARY'].copy()
s.loc[['Tom', 'Niko', 'Dean']] = [3000, 4000, 5000]
s
# Out:
# Tom          3000
# Niko         4000
# Penelope    60258
# Aria        43618
# Sofia       26125
# Dean         5000
# Zach        37565
# Name: SALARY, dtype: int64

# %%
s[s < 40000] * 2
# Out:
# Tom       6000
# Niko      8000
# Sofia    52250
# Dean     10000
# Zach     75130
# Name: SALARY, dtype: int64
