# %%
import pandas as pd
import numpy as np
#%matplotlib inline

# %%
df = pd.DataFrame({'Apples' : [10, 20, 30, 40, 50],
                  'Oranges' : [50, 60, 70, 80, 90]}, index = ['Akshay', 'Amar', 'Amitav', 'Rajat', 'Swapnil'])
df
# Out:
#          Apples  Oranges
# Akshay       10       50
# Amar         20       60
# Amitav       30       70
# Rajat        40       80
# Swapnil      50       90

# %%
df1 = pd.read_csv('data/df1', index_col = 0)
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2 = pd.read_csv('data/df2')
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
#Bar Plot
df.plot(kind = 'bar')

# %%
df['Apples'].plot(kind = 'bar')

# %%
df.loc['Akshay', :].plot(kind = 'bar')

# %%
df2['a'].plot(kind = 'bar')

# %%
#Scatter Plot
df.plot(x = 'Apples', y='Oranges', title = 'Akshay\'s Scatter Plot', kind = 'scatter')

# %%
df.plot(title = 'Line Plot') #default kind is a line plot

# %%
#KDE(Kernel Density Estimate) Plot - ingnores the index and use the values of each colum as x axis 
# and calculates the probability density for y values

df.plot(kind  = 'kde', figsize = (4,4))
# Out:
# <img src="data:image/png;base64,..." width="288">

# %%
df.plot(kind = 'hist')

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021F1032A220>,
# ...
#       dtype=object)

# %%
df2.plot.area()

# %%
df2.plot.area(alpha = 0.1)

# %%
df.plot.barh()

# %%
df.barh()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-43536289cdf9> in <module>
# ----> 1 df.barh()
#
# E:\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'barh'

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.hist()

# %%
df2.plot.hist(bins = 50)

# %%
df2.plot.hist(bins = 100)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line()

# %%
df1.plot.line(y = 'B')

# %%
df1.plot.line(y = 'B', lw = 1)

# %%
df1.plot.scatter(x = 'A', y = 'B')

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C')

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm')

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C'] * 200)
# Out:
# E:\anaconda3\lib\site-packages\matplotlib\collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C'] * 200, c = 'C', cmap = 'coolwarm')

# %%
df2.plot.box()

# %%
df2.plot.box(by = '1') #how to use this?

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])
df
# Out:
#             a         b
# 0    0.195857 -0.046034
# 1   -1.181458  0.566203
# 2    0.187173  1.045169
# 3   -0.351506 -0.223625
# 4    0.514622 -0.051238
# ..        ...       ...
# 995 -0.076118 -1.077278
# 996 -0.289409 -0.105257
# 997 -0.110214 -0.048256
# 998 -0.317633 -0.208185
# 999  0.572997  0.383922
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x = 'a', y = 'b')

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize=25)

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize=25, cmap = 'Oranges')

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.kde()

# %%
df2.plot.density()

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'Blue')

# %% [markdown]
# **%matplotlib inline**
#
# With this inline backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.
#
# This leads to static images

# %% [markdown]
# **%matplotlib notebook**
#
# will lead to interactive plots embedded within the notebook, you can zoom and resize the figure

# %%
# %matplotlib notebook
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# **figsize(16, 4)**
#
# Means 16 inch width by 4 inch height

# %% [markdown]
# **df.hist() vs. df.plot.hist()**
#
# They do different things, df.hist() will produce a separate plot for each Series whilst df.plot.hist() will produce a stacked single plot

# %% [markdown]
# **df2.plot.area(alpha = 0.4)**
#
# alpha = 1 : Opaque
# alpha = 0 : Transparent

# %%
df.plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df.plot.hist(bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# **df2.plot.hist(bins = 100)**
#
# The bins parameter tells you the number of bins that your data will be divided into. You can specify it as an integer or as a list of bin edges

# %%
df.plot.hist(bins = range(-4, 5))
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df1.plot.line(y = 'B', lw = 10)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df1.plot.line(y = 'B', lw = 1)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# **lw**
#
# Line Width : float value in points

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'G')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df1.plot.scatter(x = 'A', y = 'B', cmap = 'coolwarm'  )
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df1.plot.scatter(x = 'A', y = 'B', cmap = 'coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [raw]
# **C and cmap **
#
# c : color, sequence, or sequence of color, optional, default: 'b' The marker color.
# cmap: A colormap is a callable that takes float values between 0. and 1. as input and returns a RGB color.
#
# No  | type of x, y |  c type  | values in c |       result              |
# |___|______________|__________|_____________|___________________________|
# |1  |   single     |  scalar  |   numbers   | cmap(0.0), no matter      |
# |   |    point     |          |             |  what the value in c      |
# |___|______________|__________|_____________|___________________________|
# |2  |   array of   |  array   |   numbers   | normalize the values in c,|
# |   |    points    |          |             | cmap(normalized val in c) |
# |___|______________|__________|_____________|___________________________|
# |3  | scalar or    | scalar or| RGBA Values,|  no use of cmap,          |
# |   |  array       |  array   |Color Strings|  use colors from c        |
# |___|______________|__________|_____________|___________________________|

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C'] * 200, c = 'C', cmap = 'coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Size in points^2
# The argument s in plt.scatter denotes the markersize**2. As the documentation says
